# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/daily-new-confirmed-covid-19-deaths-per-million-people.csv')
df.head()
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 554131 entries, 0 to 554130
# Data columns (total 4 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Entity               554131 non-null  str
#  1   Code                 545183 non-null  str
#  2   Day                  554131 non-null  str
#  3   New deaths (per 1M)  554131 non-null  float64
# dtypes: float64(1), str(3)
# memory usage: 16.9 MB
# Entity                    0
# Code                   8948
# Day                       0
# New deaths (per 1M)       0
# dtype: int64

# %%
df.head()
# Out:
#         Entity Code         Day  New deaths (per 1M)
# 0  Afghanistan  AFG  2020-01-09                  0.0
# 1  Afghanistan  AFG  2020-01-10                  0.0
# 2  Afghanistan  AFG  2020-01-11                  0.0
# 3  Afghanistan  AFG  2020-01-12                  0.0
# 4  Afghanistan  AFG  2020-01-13                  0.0

# %%
df = df.dropna(subset=['Entity', 'Day', 'New deaths (per 1M)'])
df['Day'] = pd.to_datetime(df['Day'])

# %%
paises = ['Argentina', 'Brazil', 'Sweden', 'Italy','United States']
df = df[df['Entity'].isin(paises)]

# %%
df.info()
df.shape
df_bckp= df.copy()
# Out:
# <class 'pandas.DataFrame'>
# Index: 11185 entries, 20133 to 518338
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Entity               11185 non-null  str
#  1   Code                 11185 non-null  str
#  2   Day                  11185 non-null  datetime64[us]
#  3   New deaths (per 1M)  11185 non-null  float64
# dtypes: datetime64[us](1), float64(1), str(2)
# memory usage: 436.9 KB
