# %%
import pandas as pd

# %%
df = pd.read_csv('../data/daily-new-confirmed-covid-19-deaths-per-million-people.csv')
print(df.shape)
df.head()
# Out:
# (554131, 4)
#         Entity Code         Day  New deaths (per 1M)
# 0  Afghanistan  AFG  2020-01-09                  0.0
# 1  Afghanistan  AFG  2020-01-10                  0.0
# 2  Afghanistan  AFG  2020-01-11                  0.0
# 3  Afghanistan  AFG  2020-01-12                  0.0
# 4  Afghanistan  AFG  2020-01-13                  0.0
